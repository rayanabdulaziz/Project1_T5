# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('test.csv')

# %%
df
# Out:
#        employee_id         department         education gender  \
# 0             8724         Technology        Bachelor's      m
# 1            74430                 HR        Bachelor's      f
# 2            72255  Sales & Marketing        Bachelor's      m
# 3            38562        Procurement        Bachelor's      f
# 4            64486            Finance        Bachelor's      m
# ...            ...                ...               ...    ...
# 23485        53478              Legal   Below Secondary      m
# 23486        25600         Technology        Bachelor's      m
# 23487        45409                 HR        Bachelor's      f
# 23488         1186        Procurement        Bachelor's      m
# 23489         5973         Technology  Master's & above      m
#
#       recruitment_channel  age  previous_year_rating  length_of_service  \
# 0                sourcing   24                   NaN                  1
# 1                   other   31                   3.0                  5
# 2                   other   31                   1.0                  4
# 3                   other   31                   2.0                  9
# 4                sourcing   30                   4.0                  7
# ...                   ...  ...                   ...                ...
# 23485            sourcing   24                   3.0                  1
# 23486            sourcing   31                   3.0                  7
# 23487            sourcing   26                   4.0                  4
# 23488            sourcing   27                   NaN                  1
# 23489               other   40                   5.0                  5
#
#        awards_won?  avg_training_score
# 0                0                  77
# 1                0                  51
# 2                0                  47
# 3                0                  65
# 4                0                  61
# ...            ...                 ...
# 23485            0                  61
# 23486            0                  74
# 23487            0                  50
# 23488            0                  70
# 23489            0                  89
#
# [23490 rows x 10 columns]

# %%
df.head(10)
# Out:
#    employee_id         department         education gender  \
# 0         8724         Technology        Bachelor's      m
# 1        74430                 HR        Bachelor's      f
# 2        72255  Sales & Marketing        Bachelor's      m
# 3        38562        Procurement        Bachelor's      f
# 4        64486            Finance        Bachelor's      m
# 5        46232        Procurement        Bachelor's      m
# 6        54542            Finance        Bachelor's      m
# 7        67269          Analytics        Bachelor's      m
# 8        66174         Technology  Master's & above      m
# 9        76303         Technology        Bachelor's      m
#
#   recruitment_channel  age  previous_year_rating  length_of_service  \
# 0            sourcing   24                   NaN                  1
# 1               other   31                   3.0                  5
# 2               other   31                   1.0                  4
# 3               other   31                   2.0                  9
# 4            sourcing   30                   4.0                  7
# 5            sourcing   36                   3.0                  2
# 6               other   33                   5.0                  3
# 7            sourcing   36                   3.0                  3
# 8               other   51                   4.0                 11
# 9            sourcing   29                   5.0                  2
#
#    awards_won?  avg_training_score
# 0            0                  77
# 1            0                  51
# 2            0                  47
# 3            0                  65
# 4            0                  61
# 5            0                  68
# 6            0                  57
# 7            0                  85
# 8            0                  75
# 9            0                  76

# %%
df.shape
# Out:
# (23490, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   education             22456 non-null  object
#  3   gender                23490 non-null  object
#  4   recruitment_channel   23490 non-null  object
#  5   age                   23490 non-null  int64
#  6   previous_year_rating  21678 non-null  float64
#  7   length_of_service     23490 non-null  int64
#  8   awards_won?           23490 non-null  int64
#  9   avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.8+ MB

# %%
df.isna().sum()
# Out:
# employee_id                0
# department                 0
# education               1034
# gender                     0
# recruitment_channel        0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
df.dropna(subset=['education'],inplace=True)

# %%
df.education.isna().sum()
# Out:
# 0

# %%
df['education'].shape
# Out:
# (22456,)

# %%
df.dropna(subset=['previous_year_rating'],inplace=True)

# %%
df.previous_year_rating.isna().sum()
# Out:
# 0

# %%
df['previous_year_rating'].shape
# Out:
# (20819,)

# %%
df.drop('employee_id',axis=1)
# Out:
#               department         education gender recruitment_channel  age  \
# 1                     HR        Bachelor's      f               other   31
# 2      Sales & Marketing        Bachelor's      m               other   31
# 3            Procurement        Bachelor's      f               other   31
# 4                Finance        Bachelor's      m            sourcing   30
# 5            Procurement        Bachelor's      m            sourcing   36
# ...                  ...               ...    ...                 ...  ...
# 23484  Sales & Marketing        Bachelor's      m               other   28
# 23485              Legal   Below Secondary      m            sourcing   24
# 23486         Technology        Bachelor's      m            sourcing   31
# 23487                 HR        Bachelor's      f            sourcing   26
# 23489         Technology  Master's & above      m               other   40
#
#        previous_year_rating  length_of_service  awards_won?  \
# 1                       3.0                  5            0
# 2                       1.0                  4            0
# 3                       2.0                  9            0
# 4                       4.0                  7            0
# 5                       3.0                  2            0
# ...                     ...                ...          ...
# 23484                   4.0                  2            0
# 23485                   3.0                  1            0
# 23486                   3.0                  7            0
# 23487                   4.0                  4            0
# 23489                   5.0                  5            0
#
#        avg_training_score
# 1                      51
# 2                      47
# 3                      65
# 4                      61
# 5                      68
# ...                   ...
# 23484                  51
# 23485                  61
# 23486                  74
# 23487                  50
# 23489                  89
#
# [20819 rows x 9 columns]

# %%
df.describe()
# Out:
#         employee_id           age  previous_year_rating  length_of_service  \
# count  20819.000000  20819.000000           20819.00000       20819.000000
# mean   39050.468178     35.591095               3.34848           6.261732
# std    22646.036871      7.565959               1.26225           4.147909
# min        3.000000     20.000000               1.00000           1.000000
# 25%    19419.500000     30.000000               3.00000           3.000000
# 50%    38933.000000     34.000000               3.00000           5.000000
# 75%    58808.500000     39.000000               4.00000           8.000000
# max    78295.000000     60.000000               5.00000          34.000000
#
#         awards_won?  avg_training_score
# count  20819.000000        20819.000000
# mean       0.023344           63.433498
# std        0.150997           13.284129
# min        0.000000           39.000000
# 25%        0.000000           51.000000
# 50%        0.000000           60.000000
# 75%        0.000000           75.000000
# max        1.000000           99.000000

# %%
df.sort_values(by=['age','length_of_service','awards_won?'])
# Out:
#        employee_id         department         education gender  \
# 9471         42368                 HR   Below Secondary      m
# 1181          3105  Sales & Marketing        Bachelor's      m
# 1416         12623  Sales & Marketing        Bachelor's      m
# 3945         22637         Technology        Bachelor's      m
# 4145         52494        Procurement   Below Secondary      m
# ...            ...                ...               ...    ...
# 17896        48276         Technology        Bachelor's      m
# 23167        57487         Operations  Master's & above      f
# 12308        57006  Sales & Marketing        Bachelor's      m
# 11978        71243         Operations        Bachelor's      m
# 22773        58410         Technology        Bachelor's      f
#
#       recruitment_channel  age  previous_year_rating  length_of_service  \
# 9471                other   20                   5.0                  1
# 1181                other   20                   5.0                  2
# 1416                other   20                   2.0                  2
# 3945             sourcing   20                   3.0                  2
# 4145                other   20                   3.0                  2
# ...                   ...  ...                   ...                ...
# 17896               other   60                   3.0                 31
# 23167            sourcing   60                   3.0                 31
# 12308               other   60                   4.0                 32
# 11978               other   60                   3.0                 34
# 22773               other   60                   3.0                 34
#
#        awards_won?  avg_training_score
# 9471             0                  48
# 1181             0                  44
# 1416             0                  47
# 3945             0                  82
# 4145             0                  70
# ...            ...                 ...
# 17896            0                  82
# 23167            0                  63
# 12308            0                  49
# 11978            0                  56
# 22773            0                  80
#
# [20819 rows x 10 columns]

# %%
plt.figure(figsize=(12,12))
plt.grid()
plt.xlabel('age')
plt.plot(df.groupby('age')[['length_of_service','awards_won?']].sum());
plt.legend(['length_of_viceser','awards_won?'],shadow = True, loc = 0);

# %%
DF=df.groupby('department')[['awards_won?']].sum()
DF
# Out:
#                    awards_won?
# department
# Analytics                   51
# Finance                     18
# HR                          22
# Legal                        7
# Operations                 103
# Procurement                 71
# R&D                         10
# Sales & Marketing          128
# Technology                  76

# %%
plt.figure(figsize=(14,14))
sns.barplot(x=df.groupby('department')['awards_won?'].sum().index,
y=df.groupby('department')['awards_won?'].sum().values)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel('department',fontsize=14)
plt.ylabel('awards_won?',fontsize=14);

# %%
 df.gender.unique()
# Out:
# array(['f', 'm'], dtype=object)

# %%
df.gender.value_counts()
# Out:
# m    14585
# f     6234
# Name: gender, dtype: int64

# %%
df1=df.groupby('gender')[['awards_won?']].sum()
df1
# Out:
#         awards_won?
# gender
# f               154
# m               332

# %%
plt.figure(figsize=(8,8))
plt.title('gender',fontsize = 30, weight = 'bold',color='gray');
df1=df['gender'].value_counts()
plt.pie(df1,labels=['FAMALE','MALE']);
